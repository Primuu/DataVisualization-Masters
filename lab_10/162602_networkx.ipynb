# %% [markdown]
# Data visualization - Networkx Exercises - ex.10 - Adam Trentowski, 162602

# %%
import networkx as nx
import pandas as pd
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

# %%
G = nx.Graph()

# %%
G.add_node(1)
G.add_nodes_from([2, 3])
G.add_node(1)
G.add_node(2)
G.add_node(3)
G.add_node(4)
G.add_node(7)
G.add_node(9)

# %%
G.add_edge(1, 2)
G.add_edge(3, 1)
G.add_edge(2, 4)
G.add_edge(4, 1)
G.add_edge(9, 1)
G.add_edge(1, 7)
G.add_edge(2, 9)

# %%
node_list = G.nodes()
print(f'#1\n{node_list}')
# Out:
# #1
# [1, 2, 3, 4, 7, 9]

# %%
edge_list = G.edges()
print(f'#2\n{edge_list}')
# Out:
# #2
# [(1, 2), (1, 3), (1, 4), (1, 9), (1, 7), (2, 4), (2, 9)]

# %%
G.remove_node(3)
node_list = G.nodes()
print(f'#3\n{node_list}')
# Out:
# #3
# [1, 2, 4, 7, 9]

# %%
G.remove_edge(1, 2)
edge_list = G.edges()
print(f'#4\n{edge_list}')
# Out:
# #4
# [(1, 4), (1, 9), (1, 7), (2, 4), (2, 9)]

# %%
n = G.number_of_nodes()
print(f'#5\n{n}')
# Out:
# #5
# 5

# %%
m = G.number_of_edges()
print(f'#6\n{m}')
# Out:
# #6
# 5

# %%
d = G.degree(2)
print(f'#7\n{d}')
# Out:
# #7
# 2

# %%
neighbour_list = list(G.neighbors(2))
print(f'#8\n{neighbour_list}')
# Out:
# #8
# [4, 9]

# %% [markdown]
# ## Visualization in Networkx
# ### Graph

# %%
edges = [(1, 2), (1, 6), (2, 3), (2, 4), (2, 6), (3, 4), (3, 5), (4, 8), (4, 9), (6, 7)]

G.add_edges_from(edges)
nx.draw_networkx(G, label=True)

print(f'Total number of nodes: {G.number_of_nodes()}')
print(f'Total number of edges: {G.number_of_edges()}')
print(f'List of all nodes: {list(G.nodes())}')
print(f'List of all edges: {list(G.edges(data=True))}')
print(f'Degree for all nodes: {dict(G.degree())}\n')

print(f'Total number of self-loops: {nx.number_of_selfloops(G)}')
print(f'List of all nodes with self-loops: {list(nx.nodes_with_selfloops(G))}')
print(f'List of all nodes we can go to in a single step from node 2: {list(G.neighbors(2))}')
# Out:
# Total number of nodes: 9
# Total number of edges: 14
# List of all nodes: [1, 2, 4, 7, 9, 6, 3, 5, 8]
# List of all edges: [(1, 4, {}), (1, 9, {}), (1, 7, {}), (1, 2, {}), (1, 6, {}), (2, 4, {}), (2, 9, {}), (2, 3, {}), (2, 6, {}), (4, 3, {}), (4, 8, {}), (4, 9, {}), (7, 6, {}), (3, 5, {})]
# Degree for all nodes: {1: 5, 2: 5, 4: 5, 7: 2, 9: 3, 6: 3, 3: 3, 5: 1, 8: 1}
#
# Total number of self-loops: 0
# List of all nodes with self-loops: []
# List of all nodes we can go to in a single step from node 2: [4, 9, 1, 3, 6]

# %% [markdown]
# ### Graph with weighted edges

# %%
G = nx.Graph()

edges = [(1, 2, 19), (1, 6, 15), (2, 3, 6), (2, 4, 10), (2, 6, 22), (3, 4, 51), (3, 5, 14), (4, 8, 20), (4, 9, 42), (6, 7, 30)]

G.add_weighted_edges_from(edges)
nx.draw_networkx(G, with_labels=True)

# %% [markdown]
# ### Creating real undirected graph

# %%
G = nx.read_edgelist('D:/Projekty/DataVisualization/lab_10/files/SA per 1000.txt', data=[('Weight', int)])
print(list(G.nodes(data=True)))
# Out:
# [('Brazil', {}), ('511', {}), ('Venezuela', {}), ('110', {}), ('Columbia', {}), ('160', {}), ('Equador', {}), ('1864', {}), ('Peru', {}), ('1439', {}), ('Bolivia', {}), ('148', {}), ('Chile', {}), ('1126', {}), ('Paraguay', {}), ('60', {}), ('Argentina', {}), ('108', {}), ('Uruguay', {}), ('189', {})]

# %%
df = pd.read_csv('D:/Projekty/DataVisualization/lab_10/files/SA distances.txt', delim_whitespace=True, header=None, names=['n1', 'n2', 'weight'])

G = nx.from_pandas_edgelist(df, 'n1', 'n2', edge_attr='weight')
print(list(G.nodes(data=True)))
# Out:
# [('Brazil', {}), ('Venezuela', {}), ('Columbia', {}), ('Equador', {}), ('Peru', {}), ('Bolivia', {}), ('Chile', {}), ('Paraguay', {}), ('Argentina', {}), ('Uruguay', {})]
# C:\Users\Adam\AppData\Local\Temp\ipykernel_23892\3301225062.py:1: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv('D:/Projekty/DataVisualization/lab_10/files/SA distances.txt', delim_whitespace=True, header=None, names=['n1', 'n2', 'weight'])

# %%
G = nx.read_weighted_edgelist('D:/Projekty/DataVisualization/lab_10/files/SA distances.txt')
covid_rate = {
    'Brazil': 511,
    'Venezuela': 11,
    'Columbia': 160,
    'Equador': 1864,
    'Peru': 1439,
    'Bolivia': 148,
    'Chile': 1126,
    'Paraguay': 59,
    'Argentina': 108,
    'Uruguay': 189
}
covid_rate = G.nodes()
print(G.nodes())
# Out:
# ['Brazil', 'Venezuela', 'Columbia', 'Equador', 'Peru', 'Bolivia', 'Chile', 'Paraguay', 'Argentina', 'Uruguay']

# %%
for i in list(G.nodes()):
    G.nodes[i]['covid_rate'] = covid_rate[i]
    
nx.draw_networkx(G, label=True)

# %% [markdown]
# ### Weighted Graph

# %%
G = nx.Graph()

G.add_edge("Argentina", "Chile", weight=0.6)
G.add_edge("Argentina", "Brazil", weight=0.1)
G.add_edge("Brazil", "Paraguay", weight=0.2)
G.add_edge("Brazil", "Columbia", weight=0.4)
G.add_edge("Argentina", "Paraguay", weight=0.3)
G.add_edge("Argentina", "Uruguay", weight=0.2)
G.add_edge("Argentina", "Bolivia", weight=0.2)
G.add_edge("Brazil", "Peru", weight=0.5)
G.add_edge("Brazil", "Uruguay", weight=0.1)
G.add_edge("Brazil", "Venezuela", weight=0.2)
G.add_edge("Brazil", "Bolivia", weight=0.5)
G.add_edge("Chile", "Bolivia", weight=0.2)
G.add_edge("Chile", "Peru", weight=0.1)
G.add_edge("Bolivia", "Peru", weight=0.3)
G.add_edge("Bolivia", "Paraguay", weight=0.2)
G.add_edge("Peru", "Columbia", weight=0.3)
G.add_edge("Peru", "Equador", weight=0.3)
G.add_edge("Columbia", "Equador", weight=0.3)
G.add_edge("Columbia", "Venezuela", weight=0.6)

elarge = [(u, v) for (u, v, d) in G.edges(data=True) if d["weight"] > 0.5]
esmall = [(u, v) for (u, v, d) in G.edges(data=True) if d["weight"] <= 0.5]

pos = nx.spring_layout(G, seed=7)  # positions for all nodes - seed for reproducibility

nx.draw_networkx_nodes(G, pos, node_size=700)

nx.draw_networkx_edges(G, pos, edgelist=elarge, width=6)
nx.draw_networkx_edges(
    G, pos, edgelist=esmall, width=6, alpha=0.5, edge_color="b", style="dashed"
)

nx.draw_networkx_labels(G, pos, font_size=20, font_family="sans-serif")
edge_labels = nx.get_edge_attributes(G, "weight")
nx.draw_networkx_edge_labels(G, pos, edge_labels)

ax = plt.gca()
ax.margins(0.08)
plt.axis("off")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Graph layout examples

# %%
G = nx.Graph()

G.add_edge("Argentina", "Chile", weight=0.6)
G.add_edge("Argentina", "Brazil", weight=0.1)
G.add_edge("Brazil", "Paraguay", weight=0.2)
G.add_edge("Brazil", "Columbia", weight=0.2)
G.add_edge("Argentina", "Paraguay", weight=0.3)
G.add_edge("Argentina", "Uruguay", weight=0.2)
G.add_edge("Argentina", "Bolivia", weight=0.2)
G.add_edge("Brazil", "Peru", weight=0.5)
G.add_edge("Brazil", "Uruguay", weight=0.1)
G.add_edge("Brazil", "Venezuela", weight=0.2)
G.add_edge("Chile", "Bolivia", weight=0.2)
G.add_edge("Chile", "Peru", weight=0.1)
G.add_edge("Bolivia", "Peru", weight=0.3)
G.add_edge("Bolivia", "Paraguay", weight=0.2)
G.add_edge("Peru", "Columbia", weight=0.3)
G.add_edge("Peru", "Equador", weight=0.3)
G.add_edge("Columbia", "Equador", weight=0.3)
G.add_edge("Columbia", "Venezuela", weight=0.6)

# drawing in circular layout
nx.draw_circular(G, with_labels=True)
plt.show()
plt.savefig("filename1.png")

# clearing the current plot
plt.clf()

# drawing in planar layout
nx.draw_planar(G, with_labels=True)
plt.show()
plt.savefig("filename2.png")

# clearing the current plot
plt.clf()

# drawing in random layout
nx.draw_random(G, with_labels=True)
plt.show()
plt.savefig("filename3.png")

# clearing the current plot
plt.clf()

# drawing in spectral layout
nx.draw_spectral(G, with_labels=True)
plt.show()
plt.savefig("filename4.png")

# clearing the current plot
plt.clf()

# drawing in spring layout
nx.draw_spring(G, with_labels=True)
plt.show()
plt.savefig("filename5.png")

# clearing the current plot
plt.clf()

# drawing in shell layout
nx.draw_shell(G, with_labels=True)
plt.show()
plt.savefig("filename6.png")

# clearing the current plot
plt.clf()

plt.savefig("filename")
plt.show()

# %% [markdown]
# ### Node and Edges important attributes

# %%
G = nx.Graph()

G.add_edge("Argentina", "Chile", weight=0.6)
G.add_edge("Argentina", "Brazil", weight=0.1)
G.add_edge("Brazil", "Paraguay", weight=0.2)
G.add_edge("Brazil", "Columbia", weight=0.2)
G.add_edge("Argentina", "Paraguay", weight=0.3)
G.add_edge("Argentina", "Uruguay", weight=0.2)
G.add_edge("Argentina", "Bolivia", weight=0.2)
G.add_edge("Brazil", "Peru", weight=0.5)
G.add_edge("Brazil", "Uruguay", weight=0.1)
G.add_edge("Brazil", "Venezuela", weight=0.2)
G.add_edge("Brazil", "Bolivia", weight=0.5)
G.add_edge("Chile", "Bolivia", weight=0.2)
G.add_edge("Chile", "Peru", weight=0.1)
G.add_edge("Bolivia", "Peru", weight=0.3)
G.add_edge("Bolivia", "Paraguay", weight=0.2)
G.add_edge("Peru", "Columbia", weight=0.3)
G.add_edge("Peru", "Equador", weight=0.3)
G.add_edge("Columbia", "Equador", weight=0.3)
G.add_edge("Columbia", "Venezuela", weight=0.6)

print("Node Closeness Centrality", (nx.closeness_centrality(G)))
print("Node Degree Centrality", (nx.degree_centrality(G)))
print("Clustering Coefficient", (nx.clustering(G)))
print("Node Betweenness Centrality", (nx.betweenness_centrality(G)))
print("Edge Betweenness", (nx.edge_betweenness(G)))
print("Communicability", (nx.communicability(G)))
print("Average Neighbor Degree", (nx.average_neighbor_degree(G)))
print("Eigenvector Centrality", (nx.eigenvector_centrality(G)))
# Out:
# Node Closeness Centrality {'Argentina': 0.6428571428571429, 'Chile': 0.5625, 'Brazil': 0.8181818181818182, 'Paraguay': 0.5625, 'Columbia': 0.6428571428571429, 'Uruguay': 0.5294117647058824, 'Bolivia': 0.6923076923076923, 'Peru': 0.6923076923076923, 'Venezuela': 0.5294117647058824, 'Equador': 0.47368421052631576}
# Node Degree Centrality {'Argentina': 0.5555555555555556, 'Chile': 0.3333333333333333, 'Brazil': 0.7777777777777777, 'Paraguay': 0.3333333333333333, 'Columbia': 0.4444444444444444, 'Uruguay': 0.2222222222222222, 'Bolivia': 0.5555555555555556, 'Peru': 0.5555555555555556, 'Venezuela': 0.2222222222222222, 'Equador': 0.2222222222222222}
# Clustering Coefficient {'Argentina': 0.5, 'Chile': 0.6666666666666666, 'Brazil': 0.3333333333333333, 'Paraguay': 1.0, 'Columbia': 0.5, 'Uruguay': 1.0, 'Bolivia': 0.6, 'Peru': 0.4, 'Venezuela': 1.0, 'Equador': 1.0}
# ...

# %% [markdown]
# ### Importatnt whole graph metrics

# %%
nx.node_connectivity(G)
# Out:
# 2

# %%
nx.average_clustering(G)
# Out:
# 0.7

# %%
nx.average_degree_connectivity(G)
# Out:
# {5: 4.266666666666667,
#  3: 5.333333333333333,
#  7: 3.7142857142857144,
#  4: 4.0,
#  2: 5.333333333333333}

# %%
nx.average_shortest_path_length(G)
# Out:
# 1.6666666666666667

# %%
nx.density(G)
# Out:
# 0.4222222222222222
